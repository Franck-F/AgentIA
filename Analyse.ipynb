# %% [markdown]
# # Importation des bibliothèques nécessaires

# %%
import pandas as pd 
import numpy as numpy
from lxml import etree

# %% [markdown]
# # Chargement des données

# %%
dataset = ("gratification.csv")
df = pd.read_csv(dataset, sep=',', encoding='utf_8', index_col=0)
df.head(5)
# Out:
#                                                                                               creator  \
# title
# Gratification minimale d'un stagiaire étudiant ...                                                NaN
# NaN                                                 Direction de l'information légale et administr...
# NaN                                                                                               NaN
# NaN                                                                                               NaN
# NaN                                                                                               NaN
#
#                                                                                      subject  \
# title
# Gratification minimale d'un stagiaire étudiant ...                                       NaN
# NaN                                                                                      NaN
# NaN                                                 Travail - Formation, Ressources humaines
# NaN                                                                                      NaN
# NaN                                                                                      NaN
#
#                                                                                           description  \
# title
# Gratification minimale d'un stagiaire étudiant ...                                                NaN
# NaN                                                                                               NaN
# NaN                                                                                               NaN
# NaN                                                 Vous êtes stagiaire étudiant ou élève dans une...
# NaN                                                                                               NaN
#
#                                                                                             publisher  \
# title
# Gratification minimale d'un stagiaire étudiant ...                                                NaN
# NaN                                                                                               NaN
# NaN                                                                                               NaN
# NaN                                                                                               NaN
# NaN                                                 Direction de l'information légale et administr...
#
#                                                    contributor date type  \
# title
# Gratification minimale d'un stagiaire étudiant ...         NaN  NaN  NaN
# NaN                                                        NaN  NaN  NaN
# NaN                                                        NaN  NaN  NaN
# NaN                                                        NaN  NaN  NaN
# NaN                                                        NaN  NaN  NaN
#
#                                                    format identifier source  \
# title
# Gratification minimale d'un stagiaire étudiant ...    NaN        NaN    NaN
# NaN                                                   NaN        NaN    NaN
# NaN                                                   NaN        NaN    NaN
# NaN                                                   NaN        NaN    NaN
# NaN                                                   NaN        NaN    NaN
#
#                                                     ... Titre SousThemePere  \
# title                                               ...
# Gratification minimale d'un stagiaire étudiant ...  ...   NaN           NaN
# NaN                                                 ...   NaN           NaN
# NaN                                                 ...   NaN           NaN
# NaN                                                 ...   NaN           NaN
# NaN                                                 ...   NaN           NaN
#
#                                                    Fiche Texte Chapitre  URL  \
# title
# Gratification minimale d'un stagiaire étudiant ...   NaN   NaN      NaN  NaN
# NaN                                                  NaN   NaN      NaN  NaN
# NaN                                                  NaN   NaN      NaN  NaN
# NaN                                                  NaN   NaN      NaN  NaN
# NaN                                                  NaN   NaN      NaN  NaN
#
#                                                    Complement poids Source  \
# title
# Gratification minimale d'un stagiaire étudiant ...        NaN   NaN    NaN
# NaN                                                       NaN   NaN    NaN
# NaN                                                       NaN   NaN    NaN
# NaN                                                       NaN   NaN    NaN
# NaN                                                       NaN   NaN    NaN
#
#                                                    audience
# title
# Gratification minimale d'un stagiaire étudiant ...      NaN
# NaN                                                     NaN
# NaN                                                     NaN
# NaN                                                     NaN
# NaN                                                     NaN
#
# [5 rows x 30 columns]

# %%
print(df.columns)
# Out:
# Index(['creator', 'subject', 'description', 'publisher', 'contributor', 'date',
#        'type', 'format', 'identifier', 'source', 'language', 'relation',
#        'coverage', 'rights', 'SurTitre', 'Audience', 'Canal', 'Niveau', 'ID',
#        'Titre', 'SousThemePere', 'Fiche', 'Texte', 'Chapitre', 'URL',
#        'audience', 'Source'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 29 entries, Curriculum vitae (CV) - Candidature à une offre d'emploi to nan
# Data columns (total 27 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   creator        1 non-null      object
#  1   subject        1 non-null      object
#  2   description    1 non-null      object
#  3   publisher      1 non-null      object
#  4   contributor    1 non-null      object
#  5   date           1 non-null      object
#  6   type           5 non-null      object
#  7   format         1 non-null      object
#  8   identifier     1 non-null      object
#  9   source         1 non-null      object
#  10  language       1 non-null      object
#  11  relation       1 non-null      object
#  12  coverage       1 non-null      object
#  13  rights         1 non-null      object
#  14  SurTitre       1 non-null      object
#  15  Audience       1 non-null      object
#  16  Canal          1 non-null      object
#  17  Niveau         1 non-null      object
#  18  ID             8 non-null      object
#  19  Titre          7 non-null      object
#  20  SousThemePere  1 non-null      object
#  21  Fiche          1 non-null      object
#  22  Texte          0 non-null      float64
#  23  Chapitre       0 non-null      float64
#  24  URL            2 non-null      object
#  25  audience       1 non-null      object
#  26  Source         1 non-null      object
# dtypes: float64(2), object(25)
# memory usage: 6.3+ KB

# %%
df.describe(include='all')
# Out:
#                                                   creator  \
# count                                                   1
# unique                                                  1
# top     Direction de l'information légale et administr...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                     subject  \
# count                     1
# unique                    1
# top     Travail - Formation
# freq                      1
# mean                    NaN
# std                     NaN
# min                     NaN
# 25%                     NaN
# 50%                     NaN
# 75%                     NaN
# max                     NaN
#
#                                               description  \
# count                                                   1
# unique                                                  1
# top     Le curriculum vitae (CV) est un document qui p...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                 publisher  \
# count                                                   1
# unique                                                  1
# top     Direction de l'information légale et administr...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                               contributor  \
# count                                                   1
# unique                                                  1
# top     Direction de l'information légale et administr...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                        date      type    format identifier  \
# count                     1         5         1          1
# unique                    1         4         1          1
# top     modified 2024-04-12  Acronyme  text/xml     F33336
# freq                      1         2         1          1
# mean                    NaN       NaN       NaN        NaN
# std                     NaN       NaN       NaN        NaN
# min                     NaN       NaN       NaN        NaN
# 25%                     NaN       NaN       NaN        NaN
# 50%                     NaN       NaN       NaN        NaN
# 75%                     NaN       NaN       NaN        NaN
# max                     NaN       NaN       NaN        NaN
#
#                                                    source  ...  \
# count                                                   1  ...
# unique                                                  1  ...
# top     https://www.legifrance.gouv.fr/codes/section_l...  ...
# freq                                                    1  ...
# mean                                                  NaN  ...
# std                                                   NaN  ...
# min                                                   NaN  ...
# 25%                                                   NaN  ...
# 50%                                                   NaN  ...
# 75%                                                   NaN  ...
# max                                                   NaN  ...
#
#                                                    Niveau      ID  \
# count                                                   1       8
# unique                                                  1       8
# top     Curriculum vitae (CV) - Candidature à une offr...  N19806
# freq                                                    1       1
# mean                                                  NaN     NaN
# std                                                   NaN     NaN
# min                                                   NaN     NaN
# 25%                                                   NaN     NaN
# 50%                                                   NaN     NaN
# 75%                                                   NaN     NaN
# max                                                   NaN     NaN
#
#                       Titre SousThemePere  \
# count                     7             1
# unique                    7             1
# top     Travail - Formation   Recrutement
# freq                      1             1
# mean                    NaN           NaN
# std                     NaN           NaN
# min                     NaN           NaN
# 25%                     NaN           NaN
# 50%                     NaN           NaN
# 75%                     NaN           NaN
# max                     NaN           NaN
#
#                                                     Fiche Texte Chapitre  \
# count                                                   1   0.0      0.0
# unique                                                  1   NaN      NaN
# top     Offre de contrat de travail et promesse d'emba...   NaN      NaN
# freq                                                    1   NaN      NaN
# mean                                                  NaN   NaN      NaN
# std                                                   NaN   NaN      NaN
# min                                                   NaN   NaN      NaN
# 25%                                                   NaN   NaN      NaN
# 50%                                                   NaN   NaN      NaN
# 75%                                                   NaN   NaN      NaN
# max                                                   NaN   NaN      NaN
#
#                                                       URL      audience  \
# count                                                   2             1
# unique                                                  2             1
# top     https://www.legifrance.gouv.fr/codes/section_l...  Particuliers
# freq                                                    1             1
# mean                                                  NaN           NaN
# std                                                   NaN           NaN
# min                                                   NaN           NaN
# 25%                                                   NaN           NaN
# 50%                                                   NaN           NaN
# 75%                                                   NaN           NaN
# max                                                   NaN           NaN
#
#                                          Source
# count                                         1
# unique                                        1
# top     Caisse nationale d'assurance vieillesse
# freq                                          1
# mean                                        NaN
# std                                         NaN
# min                                         NaN
# 25%                                         NaN
# 50%                                         NaN
# 75%                                         NaN
# max                                         NaN
#
# [11 rows x 27 columns]

# %%
df.isnull().sum()
# Out:
# creator          28
# subject          28
# description      28
# publisher        28
# contributor      28
# date             28
# type             24
# format           28
# identifier       28
# source           28
# language         28
# relation         28
# coverage         28
# rights           28
# SurTitre         28
# Audience         28
# Canal            28
# Niveau           28
# ID               21
# Titre            22
# SousThemePere    28
# Fiche            28
# Texte            29
# Chapitre         29
# URL              27
# audience         28
# Source           28
# dtype: int64

# %%
df_new = df.dropna(how='all')
df_new.head(2)
# Out:
#                                                  creator              subject  \
# title
# NaN    Direction de l'information légale et administr...                  NaN
# NaN                                                  NaN  Travail - Formation
#
#       description publisher contributor date type format identifier source  \
# title
# NaN           NaN       NaN         NaN  NaN  NaN    NaN        NaN    NaN
# NaN           NaN       NaN         NaN  NaN  NaN    NaN        NaN    NaN
#
#        ... Niveau   ID Titre SousThemePere Fiche Texte Chapitre  URL audience  \
# title  ...
# NaN    ...    NaN  NaN   NaN           NaN   NaN   NaN      NaN  NaN      NaN
# NaN    ...    NaN  NaN   NaN           NaN   NaN   NaN      NaN  NaN      NaN
#
#       Source
# title
# NaN      NaN
# NaN      NaN
#
# [2 rows x 27 columns]

# %%
df_new.isnull().sum()
# Out:
# creator          25
# subject          25
# description      25
# publisher        25
# contributor      25
# date             25
# type             21
# format           25
# identifier       25
# source           25
# language         25
# relation         25
# coverage         25
# rights           25
# SurTitre         25
# Audience         25
# Canal            25
# Niveau           25
# ID               18
# Titre            19
# SousThemePere    25
# Fiche            25
# Texte            26
# Chapitre         26
# URL              24
# audience         25
# Source           25
# dtype: int64

# %% [markdown]
# ***lecture de fichier XLM***

# %%
from lxml import etree  
import pandas as pd

dataset = ("F2861.xml")
df = pd.read_xml(dataset)
df.head(5)
# Out:
# C:\Users\Franck\AppData\Local\Temp\ipykernel_10936\2133755294.py:5: FutureWarning: Passing literal xml to 'read_xml' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_xml(dataset)
# Traceback (most recent call last):
#
#   File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\interactiveshell.py:3577 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[100], line 5
#     df = pd.read_xml(dataset)
#
#   File c:\Program Files\Python313\Lib\site-packages\pandas\io\xml.py:1160 in read_xml
#     return _parse(
#
#   File c:\Program Files\Python313\Lib\site-packages\pandas\io\xml.py:852 in _parse
#     data_dicts = p.parse_data()
#
#   File c:\Program Files\Python313\Lib\site-packages\pandas\io\xml.py:556 in parse_data
#     self.xml_doc = self._parse_doc(self.path_or_buffer)
#
#   File c:\Program Files\Python313\Lib\site-packages\pandas\io\xml.py:647 in _parse_doc
#     document = fromstring(
#
#   File src\\lxml\\etree.pyx:3306 in lxml.etree.fromstring
#
#   File src\\lxml\\parser.pxi:1995 in lxml.etree._parseMemoryDocument
#
#   File src\\lxml\\parser.pxi:1882 in lxml.etree._parseDoc
#
#   File src\\lxml\\parser.pxi:1164 in lxml.etree._BaseParser._parseDoc
#
#   File src\\lxml\\parser.pxi:633 in lxml.etree._ParserContext._handleParseResultDoc
#
#   File src\\lxml\\parser.pxi:743 in lxml.etree._handleParseResult
#
#   File src\\lxml\\parser.pxi:672 in lxml.etree._raiseParseError
#
#   File <string>:1
# XMLSyntaxError: Start tag expected, '<' not found, line 1, column 1

# %%
#df.describe(include="all")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 33 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   title          1 non-null      object
#  1   creator        1 non-null      object
#  2   subject        1 non-null      object
#  3   description    1 non-null      object
#  4   publisher      1 non-null      object
#  5   contributor    1 non-null      object
#  6   date           1 non-null      object
#  7   type           10 non-null     object
#  8   format         1 non-null      object
#  9   identifier     1 non-null      object
#  10  source         1 non-null      object
#  11  language       1 non-null      object
#  12  relation       1 non-null      object
#  13  coverage       1 non-null      object
#  14  rights         1 non-null      object
#  15  SurTitre       1 non-null      object
#  16  Audience       1 non-null      object
#  17  Canal          1 non-null      object
#  18  Niveau         1 non-null      object
#  19  ID             16 non-null     object
#  20  Titre          15 non-null     object
#  21  SousThemePere  1 non-null      object
#  22  Fiche          1 non-null      object
#  23  Texte          0 non-null      float64
#  24  Paragraphe     1 non-null      object
#  25  Liste          0 non-null      float64
#  26  affichage      1 non-null      object
#  27  Situation      0 non-null      float64
#  28  important      2 non-null      object
#  29  URL            4 non-null      object
#  30  Complement     1 non-null      object
#  31  audience       6 non-null      object
#  32  Source         3 non-null      object
# dtypes: float64(3), object(30)
# memory usage: 10.4+ KB

# %%
df.isnull().sum()
# Out:
# title            39
# creator          39
# subject          39
# description      39
# publisher        39
# contributor      39
# date             39
# type             30
# format           39
# identifier       39
# source           39
# language         39
# relation         39
# coverage         39
# rights           39
# SurTitre         39
# Audience         39
# Canal            39
# Niveau           39
# ID               24
# Titre            25
# SousThemePere    39
# Fiche            39
# Texte            40
# Paragraphe       39
# Liste            40
# affichage        39
# Situation        40
# important        38
# URL              36
# Complement       39
# audience         34
# Source           37
# dtype: int64
